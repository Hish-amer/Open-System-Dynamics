# %%
import numpy as np
import time

from open_sys_dynamics.ladder_algebra import operators as ops
from open_sys_dynamics.utils.benchmarking import benchmark
#--------------------------------------------------------------------------------

# %%
ops.anni(5)
# Out:
# array([[0.        +0.j, 1.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j],
#        [0.        +0.j, 0.        +0.j, 1.41421356+0.j, 0.        +0.j,
#         0.        +0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 1.73205081+0.j,
#         0.        +0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         2.        +0.j],
#        [0.        +0.j, 0.        +0.j, 0.        +0.j, 0.        +0.j,
#         0.        +0.j]])
